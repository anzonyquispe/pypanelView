# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import patsy
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %%
data = pd.read_csv("turnout.csv")
formula= "turnout ~ -1 + policy_edr + policy_mail_in + policy_motor"
Y=None 
D=None 
X=None 
index= ["abb","year"] 
ignore_treat=False 
type="treat" 
outcome_type="continuous" 
treat_type=None 
by_group=False 
by_group_side=False 
by_timing=False 
theme_bw=True 
xlim=None 
ylim=None 
xlab="Year" 
ylab='State' 
gridOff=False 
legendOff=False 
legend_labs=None 
main=None 
pre_post=None 
id=None 
show_id=None 
color=None 
axis_adjust=False 
axis_lab="both" 
axis_lab_gap= [0, 0]
axis_lab_angle=None 
shade_post=False 
cex_main=15 
cex_main_sub=12 
cex_axis=8 
cex_axis_x=None 
cex_axis_y=None 
cex_lab=12 
cex_legend=12 
background=None 
style=None 
by_unit=False 
lwd=0.2 
leave_gap=False 
display_all=None 
by_cohort=False 
collapse_history=None 
report_missing=False

formula = "turnout ~ policy_edr + policy_mail_in + policy_motor -1 " 
index = ["abb","year"]
xlab = "Year"
ylab = "State"
by_timing = True 
legend_labs = ["No EDR", "EDR"]
background = "white"
cex_main = 20
cex_axis= 8
cex_lab = 12
cex_legend = 12

# %%
# %run panelview.ipynb
# Out:
# Specified labels in the order of: No EDR, EDR.
# by timing
# /var/folders/r4/lwrzx5hs7d3cxk4p5zsy7zqh0000gp/T/ipykernel_49570/4114978938.py:6: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(data[index[0]]):

# %%
data = pd.read_csv("turnout.csv")
formula= "turnout ~ -1 + policy_edr + policy_mail_in + policy_motor"
Y=None 
D=None 
X=None 
index= ["abb","year"] 
ignore_treat=False 
type="treat" 
outcome_type="continuous" 
treat_type=None 
by_group=False 
by_group_side=False 
by_timing=False 
theme_bw=True 
xlim=None 
ylim=None 
xlab="Year" 
ylab='State' 
gridOff=False 
legendOff=False 
legend_labs=None 
main=None 
pre_post=None 
id=None 
show_id=None 
color=None 
axis_adjust=False 
axis_lab="both" 
axis_lab_gap= [0, 0]
axis_lab_angle=None 
shade_post=False 
cex_main=15 
cex_main_sub=12 
cex_axis=8 
cex_axis_x=None 
cex_axis_y=None 
cex_lab=12 
cex_legend=12 
background=None 
style=None 
by_unit=False 
lwd=0.2 
leave_gap=False 
display_all=None 
by_cohort=False 
collapse_history=None 
report_missing=False

# %%
# %run panelview.ipynb
# Out:
# /var/folders/r4/lwrzx5hs7d3cxk4p5zsy7zqh0000gp/T/ipykernel_49570/4114978938.py:6: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(data[index[0]]):

# %%
data = pd.read_csv("turnout.csv")
formula= "turnout ~ -1 + policy_edr + policy_mail_in + policy_motor"
Y=None 
D=None 
X=None 
index= ["abb","year"] 
ignore_treat=False 
type="treat" 
outcome_type="continuous" 
treat_type=None 
by_group=False 
by_group_side=False 
by_timing=False 
theme_bw=True 
xlim=None 
ylim=None 
xlab="Year" 
ylab='State' 
gridOff=False 
legendOff=False 
legend_labs=None 
main=None 
pre_post=None 
id=None 
show_id=None 
color=None 
axis_adjust=False 
axis_lab="both" 
axis_lab_gap= [0, 0]
axis_lab_angle=None 
shade_post=False 
cex_main=15 
cex_main_sub=12 
cex_axis=8 
cex_axis_x=None 
cex_axis_y=None 
cex_lab=12 
cex_legend=12 
background=None 
style=None 
by_unit=False 
lwd=0.2 
leave_gap=False 
display_all=None 
by_cohort=False 
collapse_history=None 
report_missing=False
formula = "turnout ~ policy_edr + policy_mail_in + policy_motor -1 "
index = ["abb","year"]
xlab = "Year"
ylab = "State"
pre_post = True

# %%
# %run panelview.ipynb
# Out:
# /var/folders/r4/lwrzx5hs7d3cxk4p5zsy7zqh0000gp/T/ipykernel_49570/4114978938.py:6: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(data[index[0]]):
# jola

# %%
ignore_treat=False 
type="treat" 
outcome_type="continuous" 
treat_type=None 
by_group=False 
by_group_side=False 
by_timing=False 
theme_bw=True 
xlim=None 
ylim=None 
xlab="Year" 
ylab='State' 
gridOff=False 
legendOff=False 
legend_labs=None 
main=None 
pre_post=None 
id=None 
show_id=None 
color=None 
axis_adjust=False 
axis_lab="both" 
axis_lab_gap= [0, 0]
axis_lab_angle=None 
shade_post=False 
cex_main=15 
cex_main_sub=12 
cex_axis=8 
cex_axis_x=None 
cex_axis_y=None 
cex_lab=12 
cex_legend=12 
background=None 
style=None 
by_unit=False 
lwd=0.2 
leave_gap=False 
display_all=None 
by_cohort=False 
collapse_history=None 
report_missing=False

formula = "turnout ~ policy_edr + policy_mail_in + policy_motor - 1"
index = ["abb","year"]
main = "EDR Reform"
axis_lab = "time"
data = pd.read_csv("turnout.csv")

# %%
# %run panelview.ipynb
# Out:
# /var/folders/r4/lwrzx5hs7d3cxk4p5zsy7zqh0000gp/T/ipykernel_49570/4114978938.py:6: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(data[index[0]]):

# %%
data = pd.read_csv("turnout.csv")
formula= None
Y=None 
D=None 
X=None 
ignore_treat=False 
type="treat" 
outcome_type="continuous" 
treat_type=None 
by_group=False 
by_group_side=False 
by_timing=False 
theme_bw=True 
xlim=None 
ylim=None 
xlab="Year" 
ylab='State' 
gridOff=False 
legendOff=False 
legend_labs=None 
main=None 
pre_post=None 
id=None 
show_id=None 
color=None 
axis_adjust=False 
axis_lab="both" 
axis_lab_gap= [0, 0]
axis_lab_angle=None 
shade_post=False 
cex_main=15 
cex_main_sub=12 
cex_axis=8 
cex_axis_x=None 
cex_axis_y=None 
cex_lab=12 
cex_legend=12 
background=None 
style=None 
by_unit=False 
lwd=0.2 
leave_gap=False 
display_all=None 
by_cohort=False 
collapse_history=None 
report_missing=False

D = "policy_edr"
index = ["abb","year"]
xlab = "Year"
ylab = "State"
pre_post = True
main = "EDR Reform"
axis_lab = "time"

# %%
# %run panelview.ipynb
# Out:
# /var/folders/r4/lwrzx5hs7d3cxk4p5zsy7zqh0000gp/T/ipykernel_49570/4114978938.py:6: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(data[index[0]]):
# jola

# %%
capacity = pd.read_csv("capacity.csv")
formula= None
Y=None 
D=None 
X=None 
ignore_treat=False 
type="treat" 
outcome_type="continuous" 
treat_type=None 
by_group=False 
by_group_side=False 
by_timing=False 
theme_bw=True 
xlim=None 
ylim=None 
xlab=None
ylab=None
gridOff=False 
legendOff=False 
legend_labs=None 
main=None 
pre_post=None 
id=None 
show_id=None 
color=None 
axis_adjust=False 
axis_lab="both" 
axis_lab_gap= [0, 0]
axis_lab_angle=None 
shade_post=False 
cex_main=15 
cex_main_sub=12 
cex_axis=8 
cex_axis_x=None 
cex_axis_y=None 
cex_lab=12 
cex_legend=12 
background=None 
style=None 
by_unit=False 
lwd=0.2 
leave_gap=False 
display_all=None 
by_cohort=False 
collapse_history=None 
report_missing=False

# # formula = "turnout ~ policy_edr + policy_mail_in + policy_motor -1" 
# # color = ["#B0C4DE","white"]
# # by_timing = True 
# index = ["ccode","year"]
# # xlab = "Year"
# # ylab = "State"
# # data = data[~data['year'].isin([1924, 1928, 1940])]
# # formula = "turnout ~ policy_edr + policy_mail_in + policy_motor -1" 
# # index = ["abb","year"]
# # type = "treat"
# # leave_gap = True

# formula = "Capacity ~ demo + lnpop + lngdp - 1"
# # main = "Democracy and State Capacity"
# # axis_lab_gap = [2,10]


# # main = "Democracy and State Capacity: Treatment Status"
# # axis_lab_angle = 90
# # by_timing = True
# # axis_lab = "time"
# turnout = pd.read_csv("turnout.csv")

# # formula = "turnout ~ policy_edr + policy_mail_in + policy_motor - 1"
# # data = turnout
# # index = ["abb","year"]
# # axis_lab_angle = 90
# # by_timing = True
# # collapse_history = True


# formula = "Capacity ~ 1"
# data = capacity.copy()
# index = ["ccode", "year"]
# axis_lab_gap = [2,0]
# # axis_lab_angle = 90
# # collapse_history = True
# main = "Democracy and State Capacity"
# # show_id = list(range(0, 25))
# # id = capacity.ccode.unique()[25:50]
# # by_timing = True
# axis_lab = "off"
# type = "miss"


# capacity.loc[((capacity['year'] == 1960) | (capacity['year'] == 1980)), 'demo'] = np.nan

# # Set `lngdp` to NaN where year is "1990"
# capacity.loc[capacity['year'] == 1990, 'lngdp'] = np.nan

# Step 1: Create `demo2` initialized with 0s
capacity['demo2'] = 0

# Step 2: Assign -1 where polity2 < -0.5
capacity.loc[capacity['polity2'] < -0.5, 'demo2'] = -1

# Step 3: Assign 1 where polity2 > 0.5
capacity.loc[capacity['polity2'] > 0.5, 'demo2'] = 1

# data = capacity.copy()
# formula = "1 ~ demo + lngdp"
# index = ["ccode","year"]
# type = "missing"
# leave_gap = True
# axis_lab_gap = [2,10]

# data = capacity.copy()
# formula = "Capacity ~ demo2 + lngdp"
# index = ["ccode", "year"]
# axis_lab_gap = [2,10]
# main = "Regime Type"

# %%
data = capacity.copy()
formula = "Capacity ~ demo2"
index = ["ccode", "year"]
axis_lab_gap = [2]
main = "Regime Type"
axis_lab = "time"
color = ['red', 'green', 'blue']
legend_labs = ["Autocracy", "Hybrid", "Democracy"]

# %%
# %run panelview.ipynb
# Out:
# /var/folders/r4/lwrzx5hs7d3cxk4p5zsy7zqh0000gp/T/ipykernel_49570/4114978938.py:6: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(data[index[0]]):
# 3 treatment levels.
# Specified col in the order of: -1.0, 0.0, 1.0.
# Specified labels in the order of: Autocracy, Hybrid, Democracy.
